# %% [markdown]
# Name:

# %% [markdown]
# ## Problem Set 3 (Homework): Interacting with the Alpha Vantage API using Python libraries

# %% [markdown]
# Complete each step of boths parts of the notebook. The first part calls the Alpha Vantage API using the HTTP request library. The second part uses the Python Alpha Vantage library. Refer to Part 1 and Part 2 notebooks for code examples and any documentation.
#
# Documentation links:
# <br />Alpha Vantage: https://www.alphavantage.co/documentation/
# <br />Alpha Vantage Python library: https://alpha-vantage.readthedocs.io/en/latest/#
# <br />Pandas DataFrame: https://pandas.pydata.org/pandas-docs/stable/reference/frame.html

# %% [markdown]
# #### Part 1: Alpha Vantage HTTP (RESTful) API call

# %% [markdown]
# (1) Import the "requests" library:
# (1 point)

# %%
import requests
import pandas as pd
from alpha_vantage.timeseries import TimeSeries

# %% [markdown]
# (2) Assign your Alpha Vantage API key to a variable: (1 point)

# %%
api_key = "V81AV1ZI4H7MOMPF"

# %% [markdown]
# (3) Assign a stock ticker symbol to a variable: (1 point)

# %%
ticker = "amtd"

# %% [markdown]
# (4) Make an API call using the Alpha Vantage HTTP API: (5 points)
# * Compose a URL string and assign it to a variable called link
# * Format the URL with the above variables used for your API key and stock ticker symbol
# * Get daily stock data for the last 100 obervations
# * Retrieve the data as type CSV
# * Refer to the documentation: https://www.alphavantage.co/documentation/

# %%
link = f"https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&&symbol={ticker}&outputsize=compact&apikey={api_key}&datatype=csv"
print(link)
# Out:
# https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&&symbol=amtd&outputsize=compact&apikey=V81AV1ZI4H7MOMPF&datatype=csv

# %% [markdown]
# (5) Print the output from the HTTP API call: (2 points)
# * It should print as text in CSV format

# %%
amtd = requests.get(link)

# %%
print(amtd)
# Out:
# <Response [200]>

# %%
print(amtd.text)
# Out:
# timestamp,open,high,low,close,volume
# 2019-09-30,47.0900,47.2700,46.3900,46.7000,1927514
# 2019-09-27,45.5400,47.0700,45.5400,46.9700,3095100
# 2019-09-26,48.3000,48.4100,44.5800,45.3000,7129300
# 2019-09-25,48.0300,48.5300,47.9000,48.4500,1602800
# 2019-09-24,49.1500,49.2900,47.7800,48.0100,1744300
# 2019-09-23,48.9800,49.2000,48.5300,49.0600,1268900
# 2019-09-20,49.6900,50.0000,49.2000,49.2700,2022600
# 2019-09-19,49.6200,50.0200,49.2500,49.6600,1310100
# 2019-09-18,49.7000,49.7600,48.4100,49.4600,2858300
# 2019-09-17,49.6100,50.0900,49.2200,50.0200,1579300
# 2019-09-16,49.2100,49.9500,49.2100,49.8900,1351700
# 2019-09-13,49.6200,50.1300,49.6100,49.7400,1517700
# 2019-09-12,48.6300,49.6500,48.2900,49.3800,1624100
# 2019-09-11,48.8700,49.1700,47.7900,49.0700,1599600
# 2019-09-10,48.1100,48.8900,47.8500,48.5900,3450800
# 2019-09-09,46.7100,48.0500,46.7100,47.8800,2300000
# 2019-09-06,46.2400,46.5600,45.9100,46.4800,916300
# 2019-09-05,45.6500,46.7500,45.6500,46.1500,1692900
# 2019-09-04,44.7300,45.1800,44.4600,44.9500,2384300
# 2019-09-03,44.2100,44.2600,43.6700,44.0400,1472200
# 2019-08-30,44.2600,44.6900,44.1700,44.4100,1716600
# 2019-08-29,43.0900,44.1600,43.0300,43.8700,2566100
# 2019-08-28,42.1400,43.0400,42.1400,42.6000,1880500
# 2019-08-27,43.2400,43.2400,42.3000,42.5000,1615400
# 2019-08-26,43.2000,43.3700,42.7000,42.9200,2836400
# 2019-08-23,43.5200,43.9900,42.7200,42.9100,1616400
# 2019-08-22,44.2300,44.3500,43.4800,43.8400,2736400
# 2019-08-21,43.7800,44.0400,43.4800,43.8700,3123100
# 2019-08-20,43.7000,43.9200,43.2200,43.2700,2847400
# 2019-08-19,44.5100,44.7500,43.7700,43.7900,2271900
# 2019-08-16,43.4200,44.3500,43.3900,43.9200,2620800
# 2019-08-15,43.5000,43.7500,42.9300,43.1000,2349400
# 2019-08-14,43.1800,43.9500,42.9600,43.1700,2937000
# 2019-08-13,43.6100,44.8300,43.4600,44.4200,2628600
# 2019-08-12,44.0800,44.2300,43.1900,43.5700,3710200
# 2019-08-09,45.3900,46.0600,44.6850,44.7500,2625600
# 2019-08-08,46.3100,46.4300,45.6700,46.2300,4275900
# 2019-08-07,46.2300,46.2600,44.8100,45.7100,3715100
# 2019-08-06,47.1900,47.5900,46.6300,47.5200,1786400
# 2019-08-05,48.1500,48.4200,46.3914,46.7700,2847000
# 2019-08-02,49.4500,49.6800,48.8600,49.4500,3426300
# 2019-08-01,50.8919,51.1300,48.3300,49.6800,3719400
# 2019-07-31,51.5200,51.5800,50.4500,51.1000,2951800
# 2019-07-30,51.0600,51.4800,50.9200,51.3800,1873700
# 2019-07-29,52.0000,52.1700,51.3800,51.4100,2119000
# 2019-07-26,52.0100,52.4000,51.6700,52.0500,1691400
# 2019-07-25,52.5000,52.6700,51.7268,52.0200,2034100
# 2019-07-24,52.1900,52.5300,51.9700,52.4500,3695600
# 2019-07-23,51.1000,53.0559,51.0100,52.2800,7099100
# 2019-07-22,51.5900,52.4800,51.5900,52.4000,4110700
# 2019-07-19,51.1500,52.1400,51.1500,51.5900,2199000
# 2019-07-18,50.4500,51.3500,50.4500,51.0300,1946000
# 2019-07-17,50.7576,50.9500,50.1100,50.3700,1952400
# 2019-07-16,51.0500,51.6000,50.9300,50.9400,2279700
# 2019-07-15,50.9886,51.2200,50.4800,50.5400,2004600
# 2019-07-12,50.6300,51.0200,50.3900,50.9700,1664300
# 2019-07-11,49.9600,50.7100,49.6200,50.7000,1998900
# 2019-07-10,50.9000,51.1400,49.9700,50.0100,2632500
# 2019-07-09,49.9965,51.3200,49.9000,51.2500,2627800
# 2019-07-08,50.8400,51.0000,50.0033,50.2600,1888100
# 2019-07-05,50.5104,51.4800,50.5100,51.2300,1551200
# 2019-07-03,50.1000,51.1200,49.9600,50.2800,893600
# 2019-07-02,50.3500,50.3500,49.4500,49.9800,1975900
# 2019-07-01,50.5300,51.2350,50.3100,50.3700,2243800
# 2019-06-28,49.9900,50.5600,49.6900,49.9200,3439700
# 2019-06-27,48.7600,49.6900,48.7600,49.5900,2986100
# 2019-06-26,48.5800,49.3000,48.3500,48.6500,3612700
# 2019-06-25,48.2900,48.5000,47.4400,48.2900,2781700
# 2019-06-24,49.5100,49.7500,48.0100,48.0800,2864900
# 2019-06-21,49.4500,50.1200,49.3400,49.9900,3042100
# 2019-06-20,49.4900,49.7000,48.6700,49.4200,4223700
# 2019-06-19,50.3000,50.6900,48.9150,49.2800,3583700
# 2019-06-18,49.5400,50.3700,49.1900,50.0800,3149800
# 2019-06-17,50.5516,50.8700,49.8750,49.9100,1742700
# 2019-06-14,51.3100,51.4100,50.4900,50.5200,2563800
# 2019-06-13,51.1200,51.5500,50.9500,51.1000,3028400
# 2019-06-12,52.0500,52.1800,50.7000,50.9800,2155400
# 2019-06-11,53.0007,53.0100,52.0100,52.2800,1949600
# 2019-06-10,52.6600,53.4500,52.4600,52.5000,2570300
# 2019-06-07,52.0500,52.6249,52.0200,52.1100,1580300
# 2019-06-06,52.2100,52.5800,51.9900,52.3600,1344000
# 2019-06-05,52.1300,52.5678,51.7600,52.3500,2034300
# 2019-06-04,50.8500,52.2100,50.6900,52.0200,2248700
# 2019-06-03,49.6100,50.6000,49.5400,50.0100,2561800
# 2019-05-31,50.3800,50.3800,49.5600,49.7500,2766800
# 2019-05-30,50.9800,51.3200,50.4900,50.7100,1235800
# 2019-05-29,50.3200,50.9500,49.8700,50.7300,2836400
# 2019-05-28,51.8900,52.1210,50.5900,50.7600,3421100
# 2019-05-24,51.5800,52.1400,51.5100,51.9800,2712900
# 2019-05-23,51.4100,51.5700,50.8000,51.2800,3379900
# 2019-05-22,52.2500,52.5000,51.8950,51.9900,1675100
# 2019-05-21,53.2000,53.4800,52.4900,52.5200,1920400
# 2019-05-20,52.4927,53.1800,52.3800,52.7000,1483400
# 2019-05-17,52.0000,52.9900,51.9600,52.7100,2274200
# 2019-05-16,51.8000,53.1300,51.8000,52.5300,1900000
# 2019-05-15,52.3500,52.7200,51.1150,51.5100,2888700
# 2019-05-14,51.5800,53.3500,51.4800,52.9700,3078600
# 2019-05-13,52.1600,52.7900,51.3200,51.4700,2208900
# 2019-05-10,53.0600,53.7100,52.7650,53.3500,2231900
# 2019-05-09,53.0000,53.4534,51.9200,53.4000,3145900

# %% [markdown]
# #### Part 2: API call using alpha_vantage Python library
# Refer to the docs: https://alpha-vantage.readthedocs.io/en/latest/

# %% [markdown]
# (1) Import the necessary items (2 lines): (2 points)

# %%
import pandas as pd
from alpha_vantage.timeseries import TimeSeries

# %% [markdown]
# (2) Create an instance of the TimeSeries class: (2 points)
# * Use the API key variable assigned in Part 1
# * Import the data as a pandas dataframe

# %%
ts = TimeSeries(key=api_key,output_format='pandas')

# %% [markdown]
# (3) Retrieve daily stock price data by calling the API with the appropriate "get" method: (5 point)
# * Use the ticket symbol variable you used in Part 1 as an argument in the get method
# * Get the last 100 obervations
# * Store the time series data and the meta data into two separate variables on the same line
# * Refer to the docs: https://alpha-vantage.readthedocs.io/en/latest/genindex.html

# %%
data, meta_data = ts.get_daily (symbol='AMTD', outputsize='compact')

# %% [markdown]
# (4) Print the dataframe (1 point)

# %%
print(amtd_data)
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# date
# 2019-05-09  53.0000  53.4534  51.920     53.40  3145900.0
# 2019-05-10  53.0600  53.7100  52.765     53.35  2231900.0
# 2019-05-13  52.1600  52.7900  51.320     51.47  2208900.0
# 2019-05-14  51.5800  53.3500  51.480     52.97  3078600.0
# 2019-05-15  52.3500  52.7200  51.115     51.51  2888700.0
# 2019-05-16  51.8000  53.1300  51.800     52.53  1900000.0
# 2019-05-17  52.0000  52.9900  51.960     52.71  2274200.0
# 2019-05-20  52.4927  53.1800  52.380     52.70  1483400.0
# 2019-05-21  53.2000  53.4800  52.490     52.52  1920400.0
# 2019-05-22  52.2500  52.5000  51.895     51.99  1675100.0
# 2019-05-23  51.4100  51.5700  50.800     51.28  3379900.0
# 2019-05-24  51.5800  52.1400  51.510     51.98  2712900.0
# 2019-05-28  51.8900  52.1210  50.590     50.76  3421100.0
# 2019-05-29  50.3200  50.9500  49.870     50.73  2836400.0
# 2019-05-30  50.9800  51.3200  50.490     50.71  1235800.0
# 2019-05-31  50.3800  50.3800  49.560     49.75  2766800.0
# 2019-06-03  49.6100  50.6000  49.540     50.01  2561800.0
# 2019-06-04  50.8500  52.2100  50.690     52.02  2248700.0
# 2019-06-05  52.1300  52.5678  51.760     52.35  2034300.0
# 2019-06-06  52.2100  52.5800  51.990     52.36  1344000.0
# 2019-06-07  52.0500  52.6249  52.020     52.11  1580300.0
# 2019-06-10  52.6600  53.4500  52.460     52.50  2570300.0
# 2019-06-11  53.0007  53.0100  52.010     52.28  1949600.0
# 2019-06-12  52.0500  52.1800  50.700     50.98  2155400.0
# 2019-06-13  51.1200  51.5500  50.950     51.10  3028400.0
# 2019-06-14  51.3100  51.4100  50.490     50.52  2563800.0
# 2019-06-17  50.5516  50.8700  49.875     49.91  1742700.0
# 2019-06-18  49.5400  50.3700  49.190     50.08  3149800.0
# 2019-06-19  50.3000  50.6900  48.915     49.28  3583700.0
# 2019-06-20  49.4900  49.7000  48.670     49.42  4223700.0
# ...             ...      ...     ...       ...        ...
# 2019-08-19  44.5100  44.7500  43.770     43.79  2271900.0
# 2019-08-20  43.7000  43.9200  43.220     43.27  2847400.0
# 2019-08-21  43.7800  44.0400  43.480     43.87  3123100.0
# 2019-08-22  44.2300  44.3500  43.480     43.84  2736400.0
# 2019-08-23  43.5200  43.9900  42.720     42.91  1616400.0
# 2019-08-26  43.2000  43.3700  42.700     42.92  2836400.0
# 2019-08-27  43.2400  43.2400  42.300     42.50  1615400.0
# 2019-08-28  42.1400  43.0400  42.140     42.60  1880500.0
# 2019-08-29  43.0900  44.1600  43.030     43.87  2566100.0
# 2019-08-30  44.2600  44.6900  44.170     44.41  1716600.0
# 2019-09-03  44.2100  44.2600  43.670     44.04  1472200.0
# 2019-09-04  44.7300  45.1800  44.460     44.95  2384300.0
# 2019-09-05  45.6500  46.7500  45.650     46.15  1692900.0
# 2019-09-06  46.2400  46.5600  45.910     46.48   916300.0
# 2019-09-09  46.7100  48.0500  46.710     47.88  2300000.0
# 2019-09-10  48.1100  48.8900  47.850     48.59  3450800.0
# 2019-09-11  48.8700  49.1700  47.790     49.07  1599600.0
# 2019-09-12  48.6300  49.6500  48.290     49.38  1624100.0
# 2019-09-13  49.6200  50.1300  49.610     49.74  1517700.0
# 2019-09-16  49.2100  49.9500  49.210     49.89  1351700.0
# 2019-09-17  49.6100  50.0900  49.220     50.02  1579300.0
# 2019-09-18  49.7000  49.7600  48.410     49.46  2858300.0
# 2019-09-19  49.6200  50.0200  49.250     49.66  1310100.0
# 2019-09-20  49.6900  50.0000  49.200     49.27  2022600.0
# 2019-09-23  48.9800  49.2000  48.530     49.06  1268900.0
# 2019-09-24  49.1500  49.2900  47.780     48.01  1744300.0
# 2019-09-25  48.0300  48.5300  47.900     48.45  1602800.0
# 2019-09-26  48.3000  48.4100  44.580     45.30  7129300.0
# 2019-09-27  45.5400  47.0700  45.540     46.97  3095100.0
# 2019-09-30  47.0900  47.2700  46.390     46.70  1927514.0
#
# [100 rows x 5 columns]

# %% [markdown]
# (BONUS POINT) Print just the highest closing price of the last 100 obervations:
# * Refer to the pandas docs: https://pandas.pydata.org/pandas-docs/stable/

# %%
amtd_close = amtd_data['4. close']

# %%
amtd_close.max()
# Out:
# 53.4
